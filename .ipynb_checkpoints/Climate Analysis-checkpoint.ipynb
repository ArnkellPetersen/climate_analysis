# %%
from bokeh.plotting import figure, output_file, show, save, ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.transform import factor_cmap
from bokeh.io import show, curdoc, output_notebook
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, RangeTool,LinearAxis, Range1d, Select
import pandas as pd
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
widgets.FileUpload(accept='.epw', multiple=False)
# Out:
# FileUpload(value={}, accept='.epw', description='Upload')

# %%
# epw="data/GBR_London.Gatwick.037760_IWEC.epw"

widgets.FileUpload(accept='.epw', multiple=False)

# col_names=['Year','Month','Day','Hour','Seconds','Datasource','DB','DP','RH','AtmPressure','ExtHorzRad','ExtDirRad','HorzIRSky', 'GloHorzRad', 'DirNormRad','DifHorzRad','GloHorzIllum','DirNormIllum','DifHorzIllum','ZenLum','WindDir','WindSpd','TotSkyCvr','OpaqSkyCvr','Visibility','CeilingHgt','PresWeathObs,PresWeathCodes','PrecipWtr','AerosolOptDepth','SnowDepth','DaysLastSnow','Albedo','Rain','RainQuantity','-']

# df=pd.read_csv(epw,names=col_names, skiprows=8)
# df.loc[(df['Year'] > 1000,'Year')] = 2000
# # df.head()

# # Interact with specification of arguments
# @interact
# def show_articles_more_than(column1=['DB', 'RH'],column2=['DB','RH']):
#     return df[column1],df[column2]

def read_epw(epw):
    df=pd.read_csv(epw,names=col_names, skiprows=8)
    df.head()

@interact
def upload_epw(column1=['DB', 'RH'],column2=['DB','RH'], epw=widgets.FileUpload(accept='.epw', multiple=False)):
    epw_clean=epw.items()[1]
    print(epw_clean)
#     read_epw(epw_clean)
# Out:
# interactive(children=(Dropdown(description='column1', options=('DB', 'RH'), value='DB'), Dropdown(description=…

# %%
{
    "tags": [
        "hide-input",
    ]
}
epw="data/GBR_London.Gatwick.037760_IWEC.epw"

# widgets.FileUpload(accept='.epw', multiple=False)

col_names=['Year','Month','Day','Hour','Seconds','Datasource','DB','DP','RH','AtmPressure','ExtHorzRad','ExtDirRad','HorzIRSky', 'GloHorzRad', 'DirNormRad','DifHorzRad','GloHorzIllum','DirNormIllum','DifHorzIllum','ZenLum','WindDir','WindSpd','TotSkyCvr','OpaqSkyCvr','Visibility','CeilingHgt','PresWeathObs,PresWeathCodes','PrecipWtr','AerosolOptDepth','SnowDepth','DaysLastSnow','Albedo','Rain','RainQuantity','-']

df=pd.read_csv(epw,names=col_names, skiprows=8, parse_dates=[["Year","Month","Day","Hour"]])
# df.loc[(df['Year'] > 1000,'Year')] = 2000
# df.head()

f = figure(plot_height=300, plot_width=800, tools="xpan", toolbar_location=None,
           x_axis_type="datetime", x_axis_location="above",
           background_fill_color="#efefef",x_range=(1000,3000))
f.x_range = Range1d(start=1, end=8760)
# f.y_range = Range1d(start=-5, end=35)
f.line(df['DB'])
f.yaxis.axis_label = 'Dry Bulb Temperature (°C)'
show(f)
# Out:
#   <div class="bk-root" id="8eb2c14e-faa0-432b-aecd-6a362d51035b" data-root-id="1003"></div>

# %%
{
    "tags": [
        "hide-input",
    ]
}
source = ColumnDataSource(data=df[['DB','RH']])
f=figure(title="Dry Bulb vs RH", x_axis_label='Dry-Bulb Temperature (C)', y_axis_label='Relative Humidity (%)')
f.circle(x="DB",y="RH",source=source)
show(f)
# Out:
#   <div class="bk-root" id="7e67b49f-0dda-4c78-89ad-64aa09d60d4f" data-root-id="2079"></div>
